# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('products-100.csv')
df
# Out:
#     Index                                   Name  \
# 0       1   Compact Printer Air Advanced Digital
# 1       2                                 Tablet
# 2       3                   Smart Blender Cooker
# 3       4           Advanced Router Rechargeable
# 4       5           Portable Mouse Monitor Phone
# ..    ...                                    ...
# 95     96                                 Router
# 96     97     Fast Thermostat Microphone Scooter
# 97     98  Eco Heater Toaster Stove Silent Sense
# 98     99               Clean Blender Scale Lite
# 99    100                             Smart Lamp
#
#                                           Description  \
# 0       Situation organization these memory much off.
# 1         Discussion loss politics free one thousand.
# 2                                   No situation per.
# 3                     For force gas energy six laugh.
# 4   Feeling back religious however author room sci...
# ...

# %%
fig,ax=plt.subplots(2,2,figsize=(15,15))
ax[0,0].plot(df['Index'],df['Price'],color='blue',marker='o',label='Price')
ax[0,0].set_title('Price of products')
ax[0,0].tick_params(axis='x',rotation=45,width=2)
plt.legend()
ax[0,1].bar(df['Index'],df['Stock'],color='red',label='Stock')
ax[0,1].set_title('Stock of products')
ax[0,1].tick_params(axis='x',rotation=45,width=2)
plt.legend()
ax[1,0].scatter(df['Index'],df['Internal ID'],color='green',label='Internal id')        
ax[1,0].set_title('Rating of products')
ax[1,0].tick_params(axis='x',rotation=45,width=2) 
plt.legend()
plt.tight_layout()
ax[1,1].hist(df['Stock'],bins=20,color='purple',label='Currency',edgecolor='black')
ax[1,1].tick_params(axis='x',rotation=45,width=5)
plt.legend()
plt.show()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20564\2062555360.py:5: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20564\2062555360.py:9: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20564\2062555360.py:13: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
